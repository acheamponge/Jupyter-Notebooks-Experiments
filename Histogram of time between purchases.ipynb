# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

orders=pd.read_csv("orders.csv")
customers = orders[['user_id','order_placed_tm','is_first_time_purchase','is_repeat_purchase']]
histogram = customers['order_placed_tm'].hist(bins=20, figsize=(20,10))
